# %%
import requests

# Your credentials from the URL
api_token = "e47c0c51-175e-4f9a-90ca-974cc3a60f21"
# The exact API endpoint - YOU MUST FIND THIS IN THEIR DOCS
# It might look something like: "https://api.brightdata.com/scrape/linkedin/profile"
api_endpoint = "https://api.brightdata.com/your_linkedin_api_endpoint" 

headers = {
    "Authorization": f"Bearer {api_token}",
    "Content-Type": "application/json"
}

# The LinkedIn profile you want to scrape
profile_url = "https://www.linkedin.com/in/shuenn-yuen-han-60a467261/"

payload = {
    "url": profile_url,
    # Include any other parameters like "include_skills": true
}

try:
    response = requests.post(api_endpoint, json=payload, headers=headers)
    response.raise_for_status()  # Check for HTTP errors
    data = response.json()
    print(data) # This will be structured profile data
except requests.exceptions.RequestException as e:
    print(f"Error: {e}")
# Out:
# Error: 404 Client Error: Not Found for url: https://api.brightdata.com/your_linkedin_api_endpoint
